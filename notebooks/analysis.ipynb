# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import glob
import matplotlib.pyplot as plt

sys.path.append('.')
from analysis_utils import load_run, plot_cum_vmc_by_step, show_videos, compare_video_of_runs, compare_episodes_of_runs, compare_steps_of_runs, load_runs, load_master_run

# %%
# run_ids = [
#    'fixed-winds-zoo-hype-500K-vA1-1',
#    'fixed-winds-zoo-hype-500K-vA1-2',
#    'fixed-winds-zoo-hype-500K-vA1-3',
#    'fixed-winds-zoo-hype-500K-vA2-1',
#    'fixed-winds-zoo-hype-500K-vA2-2',
#    'fixed-winds-zoo-hype-500K-vA2-3',
#    'fixed-winds-zoo-hype-500K-vA3-1',
#    'fixed-winds-zoo-hype-500K-vA3-2',
#    'fixed-winds-zoo-hype-500K-vA3-3',
# ]
# run_ids = [
#    'fixed-winds-zoo-hype-500K-vB1-1',
# ]
# run_ids = [
#    'fixed-winds-zoo-hype-500K-clip3',
#    'fixed-winds-zoo-hype-500K-clip2',
#    'fixed-winds-zoo-hype-500K-clip1',
#    'fixed-winds-zoo-hype-500K-clip07',
#    'fixed-winds-zoo-hype-500K-clip05',
#    'fixed-winds-zoo-hype-500K-clip02',
# ]
# run_ids = [
#    'fixed-winds-zoo-hype-500K-clip1',
#    'fixed-winds-zoo-hype-500K-lr07',
# ]

run_ids = [
   # 'hyp-tuning-v1-1',
   # 'hyp-tuning-v2-1',
   # 'hyp-tuning-v3-1',
   # 'hyp-tuning-v5-1',
   # 'hyp-tuning-v6-1',
   # 'hyp-tuning-v1-2',
   # 'hyp-tuning-v8-1',
]

# run_ids = [
#    'vmc-fixed-wind-v2-39',
#    'vmc-fixed-wind-v2-61',
#    'vmc-fixed-wind-v2-66',
# ]

run_ids = [
   # 'vmc-fixed-wind-v2-best-hyp-1',
   # 'vmc-fixed-wind-v2-best-hyp-2',
   # 'eval-vmc-fixed-wind-v2-best-hyp-1-2',
   'eval-vmc-fixed-wind-v2-best-hyp-2-1',
]

# %%
compare_episodes_of_runs(run_ids)
# Out:
# [WARNING] cannot load eval-vmc-fixed-wind-v2-best-hyp-1-2

# %%
compare_video_of_runs(run_ids, playback_rate=2)
# Out:
# <h1>eval-vmc-fixed-wind-v2-best-hyp-2-1</h1><h2>100%</h2>
#             <video width=19% controls autoplay loop muted>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
#
#             <video width=19% controls autoplay loop muted>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
#
#             <video width=19% controls autoplay loop muted>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
#
#             <video width=19% controls autoplay loop muted>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
#
#             <video width=19% controls autoplay loop muted>
#                 <source src="data:video/mp4;base64,..." type="video/mp4">
#             </video>
#
#             <video width=19% controls autoplay loop muted>
# ...
