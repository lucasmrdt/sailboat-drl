# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python ../scripts/find_best_n_envs.py
# Out:
# n_envs = 1, time = 0.93 ms                                                   /s]
# n_envs = 2, time = 0.89 ms                                                   it]
# n_envs = 3, time = 0.82 ms                                                   it]
# n_envs = 4, time = 0.85 ms                                                   it]
# n_envs = 5, time = 0.85 ms                                                   it]
# n_envs = 6, time = 0.84 ms                                                   it]
# /Users/lucasmrdt/.brew/anaconda3/envs/sailboat-drl/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# n_envs = 7, time = 1.00 ms
# n_envs = 8, time = 0.95 ms                                                   it]
# running experiments: 100%|████████████████████████| 8/8 [11:20<00:00, 85.11s/it]
# ...

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

from sailboat_gym import SailboatLSAEnv

# %%
# best_n_envs = pickle.load(open('../output/pkl/best_n_envs.pkl', 'rb'))

best_n_envs = {1: 9.31,
2: 8.45,
3: 5.65,
4: 5.12,
5: 5.20,
6: 5.04,
7: 5.2,
8: 5.39,
9: 7.24,
10: 7.32,
11: 7.77,
12: 6.73,
13: 5.83,
14: 5.32,
15: 5.51,
16: 5.32,
17: 5.71,
18: 5.87,
19: 5.68,
20: 5.60,
21: 5.55,
22: 5.77,
23: 5.80,
24: 5.98,
25: 6.06,
26: 5.95,
27: 6.07}

time_per_step = np.array(list(best_n_envs.values())) / 1000

# %%
plt.plot(list(best_n_envs.keys()), time_per_step * 1000)
plt.xlabel('n_envs')
plt.ylabel('time per step (ms)');

# %%
plt.plot(list(best_n_envs.keys()), 1/time_per_step)
plt.xlabel('n_envs')
plt.ylabel('steps per second');

# %%
plt.subplots(figsize=(5, 4), dpi=300)
plt.plot(list(best_n_envs.keys()), (1/SailboatLSAEnv.SIM_RATE)/
time_per_step)
plt.xlabel('n_envs')
plt.ylabel('simulation factor');

# %%
time_per_step.min()
# Out:
# 0.8236236653549707
